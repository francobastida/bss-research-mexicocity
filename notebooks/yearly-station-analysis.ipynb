# %%
from pathlib import Path
import pandas as pd

YEARLY_DIR = Path("..") / "outputs" / "yearly"

df_2025 = pd.read_parquet(YEARLY_DIR / "ecobici_trips_2025.parquet")
print(df_2025.shape)
print(df_2025.dtypes)
df_2025
# Out:
# (20134900, 25)
# user_gender                       string
# user_age                         float64
# bike_id                           string
# start_station_id                   Int64
# start_date                           str
# start_time                           str
# end_station_id                     Int64
# end_date                             str
# end_time                             str
# file_year                          int64
# file_month                         int64
# source_file                          str
# start_dt                  datetime64[ms]
# end_dt                    datetime64[ms]
# trip_duration_min                float64
# trip_year                          Int64
# trip_month                         Int64
# trip_day                           Int64
# trip_hour                          Int64
# trip_weekday                       Int64
# flag_missing_start_dt               bool
# flag_missing_end_dt                 bool
# ...

# %% [markdown]
# - Are the other indicators even necessary?
